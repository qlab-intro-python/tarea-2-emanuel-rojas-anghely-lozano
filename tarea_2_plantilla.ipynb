# %% [markdown]
# # **Tarea Nº 2**

# %%
# Calificación: 14

# %% [markdown]
# Curso:          Fundamentos de Programación en Python para Macroeconomía y Finanzas
# Profesor:       Victor Fuentes Campos

# %% [markdown]
# - Fecha y hora de entrega: Sábado 6 de enero, 11:59pm
# - Agregue los nombres de las personas con las que discutió esta tarea: Angel Emanuel Rojas Chávez y Anghely Lozano
# - Envíe su tarea haciendo el `push` de su código a su repo en GitHub Classroom:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pip install -r "/content/Archivos/requirements.txt"

# %%
import pyreadstat

# %% [markdown]
# ## Filtering rows

# %% [markdown]
# 1. Import the `flights.csv` dataset. Find all flights that:
#
#     a. Had an arrival delay of three or more hours
#
#     b. Flew to Houston (IAH or HOU)
#
#     c. Were operated by United, American, or Southwest
#
#     d. Departed in spring (March, April, and June)
#
#     e. Arrived more than two hours late, but didn’t leave late
#
#     f. Were delayed by at least an hour, but made up over 30 minutes in flight 7. Departed between midnight and 5am (inclusive)

# %%
# Solution
# flights =pd.read_csv("/content/flights.csv" )
flights =pd.read_csv("flights.csv" )
flights
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 0                1  2013      1    1     517.0             515        2.0
# 1                2  2013      1    1     533.0             529        4.0
# 2                3  2013      1    1     542.0             540        2.0
# 3                4  2013      1    1     544.0             545       -1.0
# 4                5  2013      1    1     554.0             600       -6.0
# ...            ...   ...    ...  ...       ...             ...        ...
# 336771      336772  2013      9   30       NaN            1455        NaN
# 336772      336773  2013      9   30       NaN            2200        NaN
# 336773      336774  2013      9   30       NaN            1210        NaN
# 336774      336775  2013      9   30       NaN            1159        NaN
# 336775      336776  2013      9   30       NaN             840        NaN
#
#         arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin  \
# ...

# %%
# Solution a.
delayed_flights= flights.loc[ flights['arr_delay']>180, :  ]
delayed_flights
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 151            152  2013      1    1     848.0            1835      853.0
# 649            650  2013      1    1    1815.0            1325      290.0
# 673            674  2013      1    1    1842.0            1422      260.0
# 746            747  2013      1    1    2006.0            1630      216.0
# 801            802  2013      1    1    2115.0            1700      255.0
# ...            ...   ...    ...  ...       ...             ...        ...
# 335540      335541  2013      9   29    1745.0            1330      255.0
# 335720      335721  2013      9   29    2049.0            1730      199.0
# 335778      335779  2013      9   29    2327.0            1942      225.0
# 336252      336253  2013      9   30    1324.0             830      294.0
# 336757      336758  2013      9   30    2159.0            1845      194.0
#
#         arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin  \
# ...

# %%
# Solution b. HOU
houston_flights= flights.loc[ (flights['dest']=="HOU") | (flights['dest']=="IAH")]
houston_flights
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 0                1  2013      1    1     517.0             515        2.0
# 1                2  2013      1    1     533.0             529        4.0
# 32              33  2013      1    1     623.0             627       -4.0
# 81              82  2013      1    1     728.0             732       -4.0
# 89              90  2013      1    1     739.0             739        0.0
# ...            ...   ...    ...  ...       ...             ...        ...
# 336524      336525  2013      9   30    1729.0            1720        9.0
# 336527      336528  2013      9   30    1735.0            1715       20.0
# 336618      336619  2013      9   30    1859.0            1859        0.0
# 336694      336695  2013      9   30    2015.0            2015        0.0
# 336737      336738  2013      9   30    2105.0            2106       -1.0
#
#         arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin  \
# ...

# %%
# Solution c. Were operated by United, American, or Southwest
american_flights= flights.loc[ (flights['dest']=="HOU")  ##no se puede resolver porque no se concoce que codigos pertenecen de paises americanos :(
# Out:
#   File "<ipython-input-215-e58306f78d44>", line 2
#     american_flights= flights.loc[ (flights['dest']=="HOU")  ##no se puede resolver porque no se concoce que codigos pertenecen a paises americanos :()
#                                                                                                                                                        ^
# SyntaxError: incomplete input

# %%
# Solution d
flights['time_hour']= pd.to_datetime(flights['time_hour'])
flights['time_hour']
# Out:
# 0        2013-01-01 05:00:00
# 1        2013-01-01 05:00:00
# 2        2013-01-01 05:00:00
# 3        2013-01-01 05:00:00
# 4        2013-01-01 06:00:00
#                  ...
# 336771   2013-09-30 14:00:00
# 336772   2013-09-30 22:00:00
# 336773   2013-09-30 12:00:00
# 336774   2013-09-30 11:00:00
# 336775   2013-09-30 08:00:00
# Name: time_hour, Length: 336776, dtype: datetime64[ns]

# %%
# Unrecommended because of the three main differnt zones in the USA

# %%
flights['dates']= flights['time_hour'].dt.month
flights
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 0                1  2013      1    1     517.0             515        2.0
# 1                2  2013      1    1     533.0             529        4.0
# 2                3  2013      1    1     542.0             540        2.0
# 3                4  2013      1    1     544.0             545       -1.0
# 4                5  2013      1    1     554.0             600       -6.0
# ...            ...   ...    ...  ...       ...             ...        ...
# 336771      336772  2013      9   30       NaN            1455        NaN
# 336772      336773  2013      9   30       NaN            2200        NaN
# 336773      336774  2013      9   30       NaN            1210        NaN
# 336774      336775  2013      9   30       NaN            1159        NaN
# 336775      336776  2013      9   30       NaN             840        NaN
#
#         arr_time  sched_arr_time  arr_delay  ... flight  tailnum origin dest  \
# ...

# %%
date_flights= flights.loc[ (flights['dates']==3) | (flights['dates']==4) | (flights['dates']==6) ]
date_flights
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 136247      136248  2013      3    1       4.0            2159      125.0
# 136248      136249  2013      3    1      50.0            2358       52.0
# 136249      136250  2013      3    1     117.0            2245      152.0
# 136250      136251  2013      3    1     454.0             500       -6.0
# 136251      136252  2013      3    1     505.0             515      -10.0
# ...            ...   ...    ...  ...       ...             ...        ...
# 250445      250446  2013      6   30       NaN            1945        NaN
# 250446      250447  2013      6   30       NaN            1610        NaN
# 250447      250448  2013      6   30       NaN            1709        NaN
# 250448      250449  2013      6   30       NaN            2059        NaN
# 250449      250450  2013      6   30       NaN            1915        NaN
#
#         arr_time  sched_arr_time  arr_delay  ... flight  tailnum origin dest  \
# ...

# %%
# Solution e. Arrived more than two hours late, but didn’t leave late
late_flights= flights.loc[(flights["arr_delay"]>120) & (flights["dep_delay"]==0)]
late_flights
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 33011        33012  2013     10    7    1350.0            1350        0.0
# 214512      214513  2013      5   23    1810.0            1810        0.0
# 250689      250690  2013      7    1     905.0             905        0.0
#
#         arr_time  sched_arr_time  arr_delay  ... flight  tailnum origin dest  \
# 33011     1736.0            1526      130.0  ...   5181   N611QX    LGA  MSN
# 214512    2208.0            2000      128.0  ...   4626   N525MQ    LGA  CMH
# 250689    1443.0            1223      140.0  ...   1057   N337NB    LGA  MIA
#
#        air_time  distance  hour  minute           time_hour dates
# 33011     117.0       812    13      50 2013-10-07 13:00:00    10
# 214512     82.0       479    18      10 2013-05-23 18:00:00     5
# 250689    183.0      1096     9       5 2013-07-01 09:00:00     7
#
# [3 rows x 21 columns]

# %%
# Solution f. Were delayed by at least an hour, but made up over 30 minutes in flight 7. Departed between midnight and 5am (inclusive)
others_flights= flights.loc[(flights["flight"] ==7) & (flights["dep_delay"]>=60) & (flights["arr_delay"]<= flights["dep_delay"]-30)]
others_flights
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 25889        25890  2013      1   30    2006.0            1815      111.0
# 143483      143484  2013      3    8    2104.0            1815      169.0
# 159354      159355  2013      3   25    2053.0            1820      153.0
# 176471      176472  2013      4   12    2133.0            1820      193.0
# 214657      214658  2013      5   23    2205.0            1820      225.0
# 223720      223721  2013      6    2    2145.0            1820      205.0
# 234182      234183  2013      6   13    2106.0            1825      161.0
# 238832      238833  2013      6   18    2009.0            1825      104.0
# 251189      251190  2013      7    1    1939.0            1825       74.0
#
#         arr_time  sched_arr_time  arr_delay  ... flight  tailnum origin dest  \
# 25889     2247.0            2130       77.0  ...      7   N589AS    EWR  SEA
# ...

# %%
## no hay vuelos que cumplan con la ultima condicion que salgan entre la media noche y las 5am con las características anteriores
others_flights= flights.loc[(flights["flight"] ==7) & (flights["dep_delay"]>=60) & (flights["arr_delay"]<= flights["dep_delay"]-30) & (flights["hour"]>=0) & (flights["hour"]<=5)]
others_flights
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, year, month, day, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, carrier, flight, tailnum, origin, dest, air_time, distance, hour, minute, time_hour, dates]
# Index: []
#
# [0 rows x 21 columns]

# %%
# Grading: -0.5

# %% [markdown]
# 2. How many flights have a missing dep_time? What other variables are missing? What might these rows represent?

# %%
# Solution
falta_flights= flights[flights["dep_time"].isnull()]
falta_flights
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 838            839  2013      1    1       NaN            1630        NaN
# 839            840  2013      1    1       NaN            1935        NaN
# 840            841  2013      1    1       NaN            1500        NaN
# 841            842  2013      1    1       NaN             600        NaN
# 1777          1778  2013      1    2       NaN            1540        NaN
# ...            ...   ...    ...  ...       ...             ...        ...
# 336771      336772  2013      9   30       NaN            1455        NaN
# 336772      336773  2013      9   30       NaN            2200        NaN
# 336773      336774  2013      9   30       NaN            1210        NaN
# 336774      336775  2013      9   30       NaN            1159        NaN
# 336775      336776  2013      9   30       NaN             840        NaN
#
#         arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin  \
# ...

# %% [markdown]
# 3. What happens to observations **with missing values in `arr_time`** when you filter by **`arr_time == 1800`**? Why? (Hint: compare `2000 == 1800`, `1800 == 1800`, and `NA == 1800`).

# %%
# Solution
new = flights.loc[(flights["arr_time"] ==1800)]
new ## como se observa no se muestran las filas con NaN por la condicional hecha en el código
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 1327          1328  2013      1    2    1442.0            1430       12.0
# 1426          1427  2013      1    2    1600.0            1501       59.0
# 1433          1434  2013      1    2    1603.0            1517       46.0
# 2349          2350  2013      1    3    1602.0            1600        2.0
# 3333          3334  2013      1    4    1658.0            1705       -7.0
# ...            ...   ...    ...  ...       ...             ...        ...
# 334637      334638  2013      9   28    1530.0            1535       -5.0
# 334656      334657  2013      9   28    1555.0            1600       -5.0
# 334707      334708  2013      9   28    1651.0            1635       16.0
# 336376      336377  2013      9   30    1521.0            1521        0.0
# 336464      336465  2013      9   30    1643.0            1629       14.0
#
#         arr_time  sched_arr_time  arr_delay  ... flight  tailnum origin dest  \
# ...

# %% [markdown]
# 4. What does `False & None` evaluate to? Why?

# %%
# Solution
# False es un valor válido para una serie o un marco de datos de tipo booleano,
# mientras que None es un valor que indica que falta un dato.
s = pd.Series([True, False, None, pd.NA, 1, 0])
print(s)
# Out:
# 0     True
# 1    False
# 2     None
# 3     <NA>
# 4        1
# 5        0
# dtype: object

# %% [markdown]
# ## Select columns

# %% [markdown]
# 5. Brainstorm as many distinct ways as possible to select `dep_time`, `dep_delay`, `arr_time`, and `arr_delay` from `flights`.

# %%
# Solution
#metodo 1
metodo1= flights[["dep_time", "dep_delay", "arr_time","arr_delay"]]
metodo1
# Out:
#         dep_time  dep_delay  arr_time  arr_delay
# 0          517.0        2.0     830.0       11.0
# 1          533.0        4.0     850.0       20.0
# 2          542.0        2.0     923.0       33.0
# 3          544.0       -1.0    1004.0      -18.0
# 4          554.0       -6.0     812.0      -25.0
# ...          ...        ...       ...        ...
# 336771       NaN        NaN       NaN        NaN
# 336772       NaN        NaN       NaN        NaN
# 336773       NaN        NaN       NaN        NaN
# 336774       NaN        NaN       NaN        NaN
# 336775       NaN        NaN       NaN        NaN
#
# [336776 rows x 4 columns]

# %%
#metodo2
metodo2 = flights.loc[:, ['dep_time', 'dep_delay', 'arr_time', 'arr_delay']]
metodo2
# Out:
#         dep_time  dep_delay  arr_time  arr_delay
# 0          517.0        2.0     830.0       11.0
# 1          533.0        4.0     850.0       20.0
# 2          542.0        2.0     923.0       33.0
# 3          544.0       -1.0    1004.0      -18.0
# 4          554.0       -6.0     812.0      -25.0
# ...          ...        ...       ...        ...
# 336771       NaN        NaN       NaN        NaN
# 336772       NaN        NaN       NaN        NaN
# 336773       NaN        NaN       NaN        NaN
# 336774       NaN        NaN       NaN        NaN
# 336775       NaN        NaN       NaN        NaN
#
# [336776 rows x 4 columns]

# %%
# metodo3
metodo3 = flights.filter(['dep_time', 'dep_delay', 'arr_time', 'arr_delay'])

# %% [markdown]
# ## Sort columns

# %% [markdown]
# 6. Sort flights to find the most delayed flights by arrival time. Hint: End your code with head(1) to only print that row.

# %%
# Solution
retardado = flights.sort_values('arr_delay', ascending=False).dropna()
retardado
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 7072          7073  2013      1    9     641.0             900     1301.0
# 235778      235779  2013      6   15    1432.0            1935     1137.0
# 8239          8240  2013      1   10    1121.0            1635     1126.0
# 327043      327044  2013      9   20    1139.0            1845     1014.0
# 270376      270377  2013      7   22     845.0            1600     1005.0
# ...            ...   ...    ...  ...       ...             ...        ...
# 196935      196936  2013      5    4    1816.0            1820       -4.0
# 198763      198764  2013      5    6    1826.0            1830       -4.0
# 195236      195237  2013      5    2    1947.0            1949       -2.0
# 211124      211125  2013      5   20     719.0             735      -16.0
# 199668      199669  2013      5    7    1715.0            1729      -14.0
#
#         arr_time  sched_arr_time  arr_delay  ... flight  tailnum origin dest  \
# ...

# %% [markdown]
# 7. Find the top 5 flights that left earliest relative to their scheduled departure. Only show the tail number, date and number of minutes early they departed at.

# %%
# Solution
adelantado = flights.sort_values('dep_delay', ascending=True).dropna().head(5)
adelantado
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 89673        89674  2013     12    7    2040.0            2123      -43.0
# 113633      113634  2013      2    3    2022.0            2055      -33.0
# 64501        64502  2013     11   10    1408.0            1440      -32.0
# 9619          9620  2013      1   11    1900.0            1930      -30.0
# 24915        24916  2013      1   29    1703.0            1730      -27.0
#
#         arr_time  sched_arr_time  arr_delay  ... flight  tailnum origin dest  \
# 89673       40.0            2352       48.0  ...     97   N592JB    JFK  DEN
# 113633    2240.0            2338      -58.0  ...   1715   N612DL    LGA  MSY
# 64501     1549.0            1559      -10.0  ...   5713   N825AS    LGA  IAD
# 9619      2233.0            2243      -10.0  ...   1435   N934DL    LGA  TPA
# 24915     1947.0            1957      -10.0  ...    837   N208FR    LGA  DEN
#
# ...

# %%
8. How could you sort all missing values to the start?
# Out:
# Object `start` not found.

# %%
# Solution
none = flights.sort_values("dep_time",ascending=False, na_position="first")
none
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 838            839  2013      1    1       NaN            1630        NaN
# 839            840  2013      1    1       NaN            1935        NaN
# 840            841  2013      1    1       NaN            1500        NaN
# 841            842  2013      1    1       NaN             600        NaN
# 1777          1778  2013      1    2       NaN            1540        NaN
# ...            ...   ...    ...  ...       ...             ...        ...
# 151984      151985  2013      3   18       1.0            2128      153.0
# 152965      152966  2013      3   19       1.0            2250       71.0
# 26076        26077  2013      1   31       1.0            2100      181.0
# 215892      215893  2013      5   25       1.0            2359        2.0
# 131559      131560  2013      2   24       1.0            2245       76.0
#
#         arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin  \
# ...

# %% [markdown]
# ## Add new variables

# %% [markdown]
# 9. Currently `dep_time` and `arr_time` are convenient to look at, but hard to compute with because they’re not really continuous numbers. Convert them to number of minutes since midnight in new vars called `arr_time_min` and `dep_time_min`

# %%
# Solution

# %% [markdown]
# 10. Make a plot to compare `air_time` with `arr_time_min` - `dep_time_min`

# %%
# Solution

# %% [markdown]
# 11. We expect `air_time` and `arr_time_min` - `dep_time_min` to be the same, but they’re not. Why not?
# Identify a major data issue and subtle one.

# %%
# Solution

# %% [markdown]
# 12. Implement your fix to the major probelm. Remake the plot from the previous question.

# %%
# Solution

# %% [markdown]
# 13. Find the 10 most delayed flights

# %%
# Solution
los_maximos = flights['arr_delay'].nlargest(10)
print(los_maximos)
# Out:
# 7072      1272.0
# 235778    1127.0
# 8239      1109.0
# 327043    1007.0
# 270376     989.0
# 173992     931.0
# 151974     915.0
# 270987     895.0
# 87238      878.0
# 195711     875.0
# Name: arr_delay, dtype: float64

# %% [markdown]
# ## Summarizing grouped data

# %% [markdown]
# 14. Calculate average delays by destination for flights originating in NYC. Create a variable which ranks destinations from worst to best, where 1 is the worst rank.

# %%
# Solution
NYC = flights.loc[(flights["origin"]=="JFK")]
NYC
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 2                3  2013      1    1     542.0             540        2.0
# 3                4  2013      1    1     544.0             545       -1.0
# 8                9  2013      1    1     557.0             600       -3.0
# 10              11  2013      1    1     558.0             600       -2.0
# 11              12  2013      1    1     558.0             600       -2.0
# ...            ...   ...    ...  ...       ...             ...        ...
# 336766      336767  2013      9   30    2240.0            2250      -10.0
# 336767      336768  2013      9   30    2241.0            2246       -5.0
# 336768      336769  2013      9   30    2307.0            2255       12.0
# 336769      336770  2013      9   30    2349.0            2359      -10.0
# 336771      336772  2013      9   30       NaN            1455        NaN
#
#         arr_time  sched_arr_time  arr_delay  ... flight  tailnum origin dest  \
# ...

# %%
# There are more airports in NYC: LGA, NWK

# %%
average_days = NYC["arr_delay"] / NYC["arr_delay"].sum()
average_days
# Out:
# 2         0.000054
# 3        -0.000030
# 8        -0.000013
# 10       -0.000003
# 11       -0.000005
#             ...
# 336766   -0.000033
# 336767   -0.000026
# 336768    0.000002
# 336769   -0.000041
# 336771         NaN
# Name: arr_delay, Length: 111279, dtype: float64

# %% [markdown]
# 15. Which plane (`tailnum`) has the most minutes of delays total?

# %%
# Solution
total_delay= flights["dep_delay"] + flights["arr_delay"]
total_delay.dropna()
# Out:
# 0         13.0
# 1         24.0
# 2         35.0
# 3        -19.0
# 4        -31.0
#           ...
# 336765   -22.0
# 336766   -30.0
# 336767   -21.0
# 336768    13.0
# 336769   -35.0
# Length: 327346, dtype: float64

# %%
total_delay.max()
# Out:
# 2573.0

# %%
flights.loc[flights["dep_delay"]+flights["arr_delay"]==2573.0] ## SERÍA EL TAILNUM N38HA
# Out:
#       Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 7072        7073  2013      1    9     641.0             900     1301.0
#
#       arr_time  sched_arr_time  arr_delay  ... flight  tailnum origin dest  \
# 7072    1242.0            1530     1272.0  ...     51   N384HA    JFK  HNL
#
#      air_time  distance  hour  minute           time_hour dates
# 7072    640.0      4983     9       0 2013-01-09 09:00:00     1
#
# [1 rows x 21 columns]

# %% [markdown]
# 16. Which airlines only offer flights from New York to one other airport?

# %%
# Solution
flights.loc[(flights["origin"] == "JFK") & (flights["dest"]== "ATL")]
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 23              24  2013      1    1     606.0             610       -4.0
# 114            115  2013      1    1     807.0             810       -3.0
# 367            368  2013      1    1    1325.0            1330       -5.0
# 537            538  2013      1    1    1621.0            1548       33.0
# 691            692  2013      1    1    1856.0            1855        1.0
# ...            ...   ...    ...  ...       ...             ...        ...
# 335846      335847  2013      9   30     638.0             640       -2.0
# 335956      335957  2013      9   30     810.0             810        0.0
# 336255      336256  2013      9   30    1326.0            1330       -4.0
# 336400      336401  2013      9   30    1546.0            1545        1.0
# 336609      336610  2013      9   30    1853.0            1855       -2.0
#
#         arr_time  sched_arr_time  arr_delay  ... flight  tailnum origin dest  \
# ...

# %% [markdown]
# 17. Calculate the median arrival delay by airline.

# %%
# Solution
EWR_AEROLINEA = flights.loc[flights["origin"]=="EWR"]
EWR_AEROLINEA["arr_delay"].median()
# Out:
# -4.0

# %%
LGA_AEROLINEA = flights.loc[flights["origin"]=="LGA"]
LGA_AEROLINEA["arr_delay"].median()
# Out:
# -5.0

# %%
JFK_AEROLINEA = flights.loc[flights["origin"]=="JFK"]
JFK_AEROLINEA["arr_delay"].median()
# Out:
# -6.0

# %% [markdown]
# 18. ExpressJet has a median arrival delay of -1 minutes while US Airways has a median arrival delay of -6 minutes. Does this tell you that US Airways is a more reliable airline? Why or why not?

# %%
# Solution

# %% [markdown]
# 19. Median arrival delay may not be the best metric for our needs. Brainstorm at least 4 additional ways to assess the typical delay characteristics of a group of flights.

# %%
# Solution
desviacion_estandar = flights["arr_delay"].std()
desviacion_estandar
### Podríamos comparar cada retraso de llegada en relación a la desviación estandar del
# total, ya que de esta forma sabremos que tan anormal con respecto al total de vuelos
# se ha demorado en llegar
# Out:
# 44.63329169019399

# %%
# Solution
maximo = flights["arr_delay"].max()
minimo = flights["arr_delay"].min()
print(maximo,minimo)
### Podríamos comparar con los maximos y minimos del total de retrasos de llegada
#para tener una mejor referencia
# Out:
# 1272.0 -86.0

# %%
# Solution
maximo1 = flights["dep_delay"].max()
minimo1 = flights["dep_delay"].min()
print(maximo1,minimo1)
### Podríamos comparar con los maximos y minimos del total de retrasos de salida
#para tener una mejor referencia
# Out:
# 1301.0 -43.0

# %%
# Solution
RETRASOS_JFK = len(JFK_AEROLINEA.loc[JFK_AEROLINEA["arr_delay"]>0])
RETRASOS_EWR = len(EWR_AEROLINEA.loc[EWR_AEROLINEA["arr_delay"]>0])
RETRASOS_LGA =len(LGA_AEROLINEA.loc[LGA_AEROLINEA["arr_delay"]>0])
print(RETRASOS_EWR,RETRASOS_LGA,RETRASOS_JFK)
### Podríamos comparar el total de retrasos de cada aerolinea
# Out:
# 50099 40020 42885

# %% [markdown]
# 20. Write a code which calculates your delay measures separately by airline. Do particular airlines perform poorly on multiple metrics?

# %%
# Solution
RETRASOS_JFK = len(JFK_AEROLINEA.loc[JFK_AEROLINEA["arr_delay"]>0])
RETRASOS_EWR = len(EWR_AEROLINEA.loc[EWR_AEROLINEA["arr_delay"]>0])
RETRASOS_LGA =len(LGA_AEROLINEA.loc[LGA_AEROLINEA["arr_delay"]>0])
print(RETRASOS_EWR,RETRASOS_LGA,RETRASOS_JFK)

EWR_AEROLINEA = flights.loc[flights["origin"]=="EWR"]
EWR= EWR_AEROLINEA["arr_delay"].median()
print(EWR)

LGA_AEROLINEA = flights.loc[flights["origin"]=="LGA"]
LGA = LGA_AEROLINEA["arr_delay"].median()
print(LGA)

JFK_AEROLINEA = flights.loc[flights["origin"]=="JFK"]
JKF = JFK_AEROLINEA["arr_delay"].median()
print(JKF)

# Al parecer los que tienen menores numeros de retrasos tienen mayor promedio
# de tiempo de demora de llegada.
# Out:
# 50099 40020 42885
# -4.0
# -5.0
# -6.0
